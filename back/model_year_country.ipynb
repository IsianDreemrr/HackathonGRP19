# %%
from flask import jsonify
from connect_db import execute_query
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import pickle
from app import app  # Importer l'application Flask

# %%
with app.app_context():
    query = "SELECT * FROM olympic_medals"
    data = execute_query(query)
    json_data = jsonify(data)
    
    # Extraire les données JSON de l'objet Response
    real_data = json_data.get_json()
    real_data
# Out:
# Connexion réussie
# Connexion fermée

# %%
medals = pd.DataFrame(real_data)
medals.head()
# Out:
#       athlete_full_name                                        athlete_url  \
# 0  Stefania CONSTANTINI  https://olympics.com/en/athletes/stefania-cons...
# 1          Amos MOSANER      https://olympics.com/en/athletes/amos-mosaner
# 2      Kristin SKASLIEN  https://olympics.com/en/athletes/kristin-skaslien
# 3    Magnus NEDREGOTTEN  https://olympics.com/en/athletes/magnus-nedreg...
# 4         Almida DE VAL     https://olympics.com/en/athletes/almida-de-val
#
#   country_3_letter_code country_code country_name discipline_title  \
# 0                   ITA           IT        Italy          Curling
# 1                   ITA           IT        Italy          Curling
# 2                   NOR           NO       Norway          Curling
# 3                   NOR           NO       Norway          Curling
# 4                   SWE           SE       Sweden          Curling
#
#   event_gender    event_title     id medal_type participant_title  \
# 0        Mixed  Mixed Doubles  21698       GOLD             Italy
# 1        Mixed  Mixed Doubles  21699       GOLD             Italy
# 2        Mixed  Mixed Doubles  21700     SILVER            Norway
# 3        Mixed  Mixed Doubles  21701     SILVER            Norway
# 4        Mixed  Mixed Doubles  21702     BRONZE            Sweden
#
#   participant_type     slug_game
# 0         GameTeam  beijing-2022
# 1         GameTeam  beijing-2022
# 2         GameTeam  beijing-2022
# 3         GameTeam  beijing-2022
# 4         GameTeam  beijing-2022

# %%
# Renommer les colonnes si nécessaire pour faciliter l'accès
# medals.columns = ['','discipline_title', 'slug_game', 'event_title', 'event_gender', 'medal_type', 'participant_type', 'participant_title', 'athlete_url', 'athlete_full_name', 'country_name', 'country_code', 'country_3_letter_code']

medals.drop(['discipline_title', 'event_title', 'event_gender', 'participant_type', 'participant_title', 'athlete_url', 'athlete_full_name', 'country_code', 'country_3_letter_code'], axis=1, inplace=True)
# Créer un DataFrame avec les médailles agrégées par pays et par année
df_medals = medals.groupby(['country_name', 'slug_game', 'medal_type']).size().unstack(fill_value=0).reset_index()
print(df_medals.head(100))
# Out:
# medal_type country_name         slug_game  BRONZE  GOLD  SILVER
# 0           Afghanistan      beijing-2008       1     0       0
# 1           Afghanistan       london-2012       1     0       0
# 2               Algeria      atlanta-1996       1     2       0
# 3               Algeria    barcelona-1992       1     1       0
# 4               Algeria      beijing-2008       1     0       1
# ..                  ...               ...     ...   ...     ...
# 95              Austria  los-angeles-1984       1     1       1
# 96              Austria    melbourne-1956       4     0       0
# 97              Austria  mexico-city-1968       3     0       2
# 98              Austria     montreal-1976       1     0       0
# 99              Austria       moscow-1980       1     1       3
#
# [100 rows x 5 columns]

# %%
df_medals.rename(columns= {'medal_type': '','country_name': 'country', 'slug_game': 'year', 'BRONZE': 'bronze', 'GOLD': 'gold', 'SILVER': 'silver'}, inplace=True)
df_medals
# Out:
# medal_type      country              year  bronze  gold  silver
# 0           Afghanistan      beijing-2008       1     0       0
# 1           Afghanistan       london-2012       1     0       0
# 2               Algeria      atlanta-1996       1     2       0
# 3               Algeria    barcelona-1992       1     1       0
# 4               Algeria      beijing-2008       1     0       1
# ...                 ...               ...     ...   ...     ...
# 1774             Zambia      atlanta-1996       0     0       1
# 1775             Zambia  los-angeles-1984       1     0       0
# 1776           Zimbabwe       athens-2004       1     1       1
# 1777           Zimbabwe      beijing-2008       0     1       3
# 1778           Zimbabwe       moscow-1980       0     1       0
#
# [1779 rows x 5 columns]

# %%
df_medals['year'] = df_medals['year'].apply(lambda x: int(x.split('-')[-1]))
df_medals
# Out:
# medal_type      country  year  bronze  gold  silver
# 0           Afghanistan  2008       1     0       0
# 1           Afghanistan  2012       1     0       0
# 2               Algeria  1996       1     2       0
# 3               Algeria  1992       1     1       0
# 4               Algeria  2008       1     0       1
# ...                 ...   ...     ...   ...     ...
# 1774             Zambia  1996       0     0       1
# 1775             Zambia  1984       1     0       0
# 1776           Zimbabwe  2004       1     1       1
# 1777           Zimbabwe  2008       0     1       3
# 1778           Zimbabwe  1980       0     1       0
#
# [1779 rows x 5 columns]

# %%
countries = df_medals['country'].unique()
i = 0
for country in countries:
    df_medals.loc[df_medals['country'] == country, 'countryId'] = i
    i += int(1)
df_medals
# Out:
# medal_type      country  year  bronze  gold  silver  countryId
# 0           Afghanistan  2008       1     0       0        0.0
# 1           Afghanistan  2012       1     0       0        0.0
# 2               Algeria  1996       1     2       0        1.0
# 3               Algeria  1992       1     1       0        1.0
# 4               Algeria  2008       1     0       1        1.0
# ...                 ...   ...     ...   ...     ...        ...
# 1774             Zambia  1996       0     0       1      152.0
# 1775             Zambia  1984       1     0       0      152.0
# 1776           Zimbabwe  2004       1     1       1      153.0
# 1777           Zimbabwe  2008       0     1       3      153.0
# 1778           Zimbabwe  1980       0     1       0      153.0
#
# [1779 rows x 6 columns]

# %%
dict_country = {}
for i in range(len(df_medals)):
    id = df_medals.loc[i, 'countryId']
    if id not in dict_country:
        dict_country[id] = df_medals.loc[i, 'country']

dict_country
# Out:
# {0.0: 'Afghanistan',
#  1.0: 'Algeria',
#  2.0: 'Argentina',
#  3.0: 'Armenia',
#  4.0: 'Australasia',
#  5.0: 'Australia',
#  6.0: 'Austria',
#  7.0: 'Azerbaijan',
#  8.0: 'Bahamas',
#  9.0: 'Bahrain',
#  10.0: 'Barbados',
#  11.0: 'Belarus',
#  12.0: 'Belgium',
#  13.0: 'Bermuda',
#  14.0: 'Bohemia',
#  15.0: 'Botswana',
#  16.0: 'Brazil',
#  17.0: 'Bulgaria',
#  18.0: 'Burkina Faso',
#  19.0: 'Burundi',
#  20.0: 'Cameroon',
#  21.0: 'Canada',
#  22.0: 'Chile',
#  23.0: 'Chinese Taipei',
#  24.0: 'Colombia',
#  25.0: 'Costa Rica',
#  26.0: 'Croatia',
#  27.0: 'Cuba',
#  28.0: 'Cyprus',
#  29.0: 'Czech Republic',
#  30.0: 'Czechoslovakia',
#  31.0: "Côte d'Ivoire",
#  32.0: "Democratic People's Republic of Korea",
#  33.0: 'Denmark',
#  34.0: 'Djibouti',
#  35.0: 'Dominican Republic',
#  36.0: 'Ecuador',
#  37.0: 'Egypt',
#  38.0: 'Eritrea',
#  39.0: 'Estonia',
#  40.0: 'Ethiopia',
#  41.0: 'Federal Republic of Germany',
#  42.0: 'Fiji',
#  43.0: 'Finland',
#  44.0: 'France',
#  45.0: 'Gabon',
#  46.0: 'Georgia',
#  47.0: 'German Democratic Republic (Germany)',
#  48.0: 'Germany',
#  49.0: 'Ghana',
#  50.0: 'Great Britain',
#  51.0: 'Greece',
#  52.0: 'Grenada',
#  53.0: 'Guatemala',
#  54.0: 'Guyana',
#  55.0: 'Haiti',
#  56.0: 'Hong Kong, China',
#  57.0: 'Hungary',
#  58.0: 'Iceland',
#  59.0: 'Independent Olympic Athletes',
#  60.0: 'India',
#  61.0: 'Indonesia',
#  62.0: 'Iraq',
#  63.0: 'Ireland',
#  64.0: 'Islamic Republic of Iran',
#  65.0: 'Israel',
#  66.0: 'Italy',
#  67.0: 'Jamaica',
#  68.0: 'Japan',
#  69.0: 'Jordan',
#  70.0: 'Kazakhstan',
#  71.0: 'Kenya',
#  72.0: 'Kosovo',
#  73.0: 'Kuwait',
#  74.0: 'Kyrgyzstan',
#  75.0: 'Latvia',
#  76.0: 'Lebanon',
#  77.0: 'Liechtenstein',
#  78.0: 'Lithuania',
#  79.0: 'Luxembourg',
#  80.0: 'MIX',
#  81.0: 'Malaysia',
#  82.0: 'Mauritius',
#  83.0: 'Mexico',
#  84.0: 'Mongolia',
#  85.0: 'Montenegro',
#  86.0: 'Morocco',
#  87.0: 'Mozambique',
#  88.0: 'Namibia',
#  89.0: 'Netherlands',
#  90.0: 'Netherlands Antilles',
#  91.0: 'New Zealand',
#  92.0: 'Niger',
#  93.0: 'Nigeria',
#  94.0: 'North Macedonia',
#  95.0: 'Norway',
#  96.0: 'Olympic Athletes from Russia',
#  97.0: 'Pakistan',
#  98.0: 'Panama',
#  99.0: 'Paraguay',
#  100.0: "People's Republic of China",
#  101.0: 'Peru',
#  102.0: 'Philippines',
#  103.0: 'Poland',
#  104.0: 'Portugal',
#  105.0: 'Puerto Rico',
#  106.0: 'Qatar',
#  107.0: 'ROC',
#  108.0: 'Republic of Korea',
#  109.0: 'Republic of Moldova',
#  110.0: 'Romania',
#  111.0: 'Russian Federation',
#  112.0: 'Samoa',
#  113.0: 'San Marino',
#  114.0: 'Saudi Arabia',
#  115.0: 'Senegal',
#  116.0: 'Serbia',
#  117.0: 'Serbia and Montenegro',
#  118.0: 'Singapore',
#  119.0: 'Slovakia',
#  120.0: 'Slovenia',
#  121.0: 'South Africa',
#  122.0: 'Soviet Union',
#  123.0: 'Spain',
#  124.0: 'Sri Lanka',
#  125.0: 'Sudan',
#  126.0: 'Suriname',
#  127.0: 'Sweden',
#  128.0: 'Switzerland',
#  129.0: 'Syrian Arab Republic',
#  130.0: 'Tajikistan',
#  131.0: 'Thailand',
#  132.0: 'Togo',
#  133.0: 'Tonga',
#  134.0: 'Trinidad and Tobago',
#  135.0: 'Tunisia',
#  136.0: 'Turkey',
#  137.0: 'Turkmenistan',
#  138.0: 'Uganda',
#  139.0: 'Ukraine',
#  140.0: 'Unified Team',
#  141.0: 'United Arab Emirates',
#  142.0: 'United Arab Republic',
#  143.0: 'United Republic of Tanzania',
#  144.0: 'United States of America',
#  145.0: 'Uruguay',
#  146.0: 'Uzbekistan',
#  147.0: 'Venezuela',
#  148.0: 'Vietnam',
#  149.0: 'Virgin Islands, US',
#  150.0: 'West Indies Federation',
#  151.0: 'Yugoslavia',
#  152.0: 'Zambia',
#  153.0: 'Zimbabwe'}

# %%
import json

with open("contries.json", "w") as f:
    json.dump(dict_country, f)

# %%
# Séparation des caractéristiques et de la cible
mlX, mly = df_medals[['year', 'countryId']].values, df_medals[['gold', 'silver', 'bronze']].values

# %%
# Division des données en données d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(mlX, mly, test_size=0.30, random_state=0)

# %%
# Entrainement du modèle
modelml = RandomForestRegressor(max_depth=10000, random_state=0)
modelml.fit(mlX, mly)
# Out:
# RandomForestRegressor(max_depth=10000, random_state=0)

# %%
modelml.predict([[2024, 1.0]])
# Out:
# array([[0.56, 1.3 , 1.24]])

# %%
# Importation des bibliothèques
import pickle
import os
# Création d'un dossier s'il n'existe pas
if not os.path.exists('./models'):
    os.mkdir('models')
    pass
# Sauvegarde du modèle
pickle.dump(modelml, open('./models/medals_y_c_model.pkl','wb'))
