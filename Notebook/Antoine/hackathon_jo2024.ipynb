# %% [markdown]
# # Hackaton Prédiction - JO 2024

# %%
import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# %% [markdown]
# ### ATHLETES - olympic_athletes.json

# %%
# Chemin vers le fichier JSON
json_file = './files/olympic_athletes.json'

# Lire le fichier JSON
df_athletes = pd.read_json(json_file)

# Afficher les premières lignes du DataFrame
df_athletes.head()
# Out:
#                                          athlete_url       athlete_full_name  \
# 0  https://olympics.com/en/athletes/cooper-woods-...  Cooper WOODS-TOPALOVIC
# 1          https://olympics.com/en/athletes/elofsson          Felix ELOFSSON
# 2     https://olympics.com/en/athletes/dylan-walczyk           Dylan WALCZYK
# 3     https://olympics.com/en/athletes/olli-penttala           Olli PENTTALA
# 4          https://olympics.com/en/athletes/reikherd        Dmitriy REIKHERD
#
#    games_participations        first_game  athlete_year_birth athlete_medals  \
# 0                     1      Beijing 2022              2000.0           None
# 1                     2  PyeongChang 2018              1995.0           None
# 2                     1      Beijing 2022              1993.0           None
# 3                     1      Beijing 2022              1995.0           None
# 4                     1      Beijing 2022              1989.0           None
#
#     bio
# 0  None
# 1  None
# 2  None
# ...

# %%
# Combien de lignes ? Combien de colonnes ?
print('Il y a ' + str(df_athletes.shape[0]) + ' lignes et ' + str(df_athletes.shape[1]) + ' colonnes')
# Out:
# Il y a 75904 lignes et 7 colonnes

# %%
# Afficher le type de données dans chaque colonne
df_athletes.dtypes
# Out:
# athlete_url              object
# athlete_full_name        object
# games_participations      int64
# first_game               object
# athlete_year_birth      float64
# athlete_medals           object
# bio                      object
# dtype: object

# %%
# Y a-t'il des lignes dupliquée ? Si oui, les supprimer
print('Il y a ' + str(df_athletes.duplicated().sum()) + ' ligne(s) dupliquée(s)')
# Out:
# Il y a 0 ligne(s) dupliquée(s)

# %%
# Afficher le nombre de données manquantes pour chaque colonne
df_athletes.isnull().sum()
# Out:
# athlete_url                 0
# athlete_full_name           0
# games_participations        0
# first_game                 22
# athlete_year_birth       2456
# athlete_medals          60552
# bio                     53062
# dtype: int64

# %% [markdown]
# ### Résultats - olympic_results.html

# %%
# Chemin vers le fichier HTML ou URL
html_file = './files/olympic_results.html'

# Lire les tables du fichier HTML
dfs_html = pd.read_html(html_file)
df_results = dfs_html[0]

# Afficher la première table (si le fichier contient plusieurs tables)
df_results.head()
# Out:
#    Unnamed: 0 discipline_title    event_title     slug_game participant_type  \
# 0           0          Curling  Mixed Doubles  beijing-2022         GameTeam
# 1           1          Curling  Mixed Doubles  beijing-2022         GameTeam
# 2           2          Curling  Mixed Doubles  beijing-2022         GameTeam
# 3           3          Curling  Mixed Doubles  beijing-2022         GameTeam
# 4           4          Curling  Mixed Doubles  beijing-2022         GameTeam
#
#   medal_type                                           athletes rank_equal  \
# 0       GOLD  [('Stefania CONSTANTINI', 'https://olympics.co...      False
# 1     SILVER  [('Kristin SKASLIEN', 'https://olympics.com/en...      False
# 2     BRONZE  [('Almida DE VAL', 'https://olympics.com/en/at...      False
# 3        NaN  [('Jennifer DODDS', 'https://olympics.com/en/a...      False
# 4        NaN  [('Rachel HOMAN', 'https://olympics.com/en/ath...      False
#
# ...

# %%
# Combien de lignes ? Combien de colonnes ?
print('Il y a ' + str(df_results.shape[0]) + ' lignes et ' + str(df_results.shape[1]) + ' colonnes')
# Out:
# Il y a 162804 lignes et 16 colonnes

# %%
# Afficher le type de données dans chaque colonne
df_results.dtypes
# Out:
# Unnamed: 0                int64
# discipline_title         object
# event_title              object
# slug_game                object
# participant_type         object
# medal_type               object
# athletes                 object
# rank_equal               object
# rank_position            object
# country_name             object
# country_code             object
# country_3_letter_code    object
# athlete_url              object
# athlete_full_name        object
# value_unit               object
# value_type               object
# dtype: object

# %%
# Y a-t'il des lignes dupliquée ? Si oui, les supprimer
print('Il y a ' + str(df_results.duplicated().sum()) + ' ligne(s) dupliquée(s)')
# Out:
# Il y a 0 ligne(s) dupliquée(s)

# %%
# Afficher le nombre de données manquantes pour chaque colonne
df_results.isnull().sum()
# Out:
# Unnamed: 0                    0
# discipline_title              0
# event_title                   0
# slug_game                     0
# participant_type              0
# medal_type               142598
# athletes                 154828
# rank_equal               130278
# rank_position              3878
# country_name                  0
# country_code               5036
# country_3_letter_code         0
# athlete_url               32813
# athlete_full_name         21158
# value_unit                84158
# value_type                72755
# dtype: int64

# %% [markdown]
# ### Médailles - olympic_medals.xlsx

# %%
# Chemin vers le fichier Excel
excel_file = './files/olympic_medals.xlsx'

# Lire le fichier Excel
df_medals = pd.read_excel(excel_file)

# Afficher les premières lignes du DataFrame
df_medals.head()
# Out:
#    Unnamed: 0 discipline_title     slug_game    event_title event_gender  \
# 0           0          Curling  beijing-2022  Mixed Doubles        Mixed
# 1           1          Curling  beijing-2022  Mixed Doubles        Mixed
# 2           2          Curling  beijing-2022  Mixed Doubles        Mixed
# 3           3          Curling  beijing-2022  Mixed Doubles        Mixed
# 4           4          Curling  beijing-2022  Mixed Doubles        Mixed
#
#   medal_type participant_type participant_title  \
# 0       GOLD         GameTeam             Italy
# 1       GOLD         GameTeam             Italy
# 2     SILVER         GameTeam            Norway
# 3     SILVER         GameTeam            Norway
# 4     BRONZE         GameTeam            Sweden
#
#                                          athlete_url     athlete_full_name  \
# 0  https://olympics.com/en/athletes/stefania-cons...  Stefania CONSTANTINI
# 1      https://olympics.com/en/athletes/amos-mosaner          Amos MOSANER
# ...

# %%
# Combien de lignes ? Combien de colonnes ?
print('Il y a ' + str(df_medals.shape[0]) + ' lignes et ' + str(df_medals.shape[1]) + ' colonnes')
# Out:
# Il y a 21697 lignes et 13 colonnes

# %%
# Afficher le type de données dans chaque colonne
df_medals.dtypes
# Out:
# Unnamed: 0                int64
# discipline_title         object
# slug_game                object
# event_title              object
# event_gender             object
# medal_type               object
# participant_type         object
# participant_title        object
# athlete_url              object
# athlete_full_name        object
# country_name             object
# country_code             object
# country_3_letter_code    object
# dtype: object

# %%
# Y a-t'il des lignes dupliquée ? Si oui, les supprimer
print('Il y a ' + str(df_medals.duplicated().sum()) + ' ligne(s) dupliquée(s)')
# Out:
# Il y a 0 ligne(s) dupliquée(s)

# %%
# Afficher le nombre de données manquantes pour chaque colonne
df_medals.isnull().sum()
# Out:
# Unnamed: 0                   0
# discipline_title             0
# slug_game                    0
# event_title                  0
# event_gender                 0
# medal_type                   0
# participant_type             0
# participant_title        15113
# athlete_url               4670
# athlete_full_name         3624
# country_name                 0
# country_code              1502
# country_3_letter_code        0
# dtype: int64

# %% [markdown]
# ### Hôtes - olympic_hosts.xml

# %%
# Chemin vers le fichier XML
xml_file = './files/olympic_hosts.xml'

# Lire le fichier XML
df_hosts = pd.read_xml(xml_file)

# Afficher les premières lignes du DataFrame
df_hosts.head()
# Out:
#    index         game_slug         game_end_date       game_start_date  \
# 0      0      beijing-2022  2022-02-20T12:00:00Z  2022-02-04T15:00:00Z
# 1      1        tokyo-2020  2021-08-08T14:00:00Z  2021-07-23T11:00:00Z
# 2      2  pyeongchang-2018  2018-02-25T08:00:00Z  2018-02-08T23:00:00Z
# 3      3          rio-2016  2016-08-21T21:00:00Z  2016-08-05T12:00:00Z
# 4      4        sochi-2014  2014-02-23T16:00:00Z  2014-02-07T04:00:00Z
#
#         game_location         game_name game_season  game_year
# 0               China      Beijing 2022      Winter       2022
# 1               Japan        Tokyo 2020      Summer       2020
# 2   Republic of Korea  PyeongChang 2018      Winter       2018
# 3              Brazil          Rio 2016      Summer       2016
# 4  Russian Federation        Sochi 2014      Winter       2014

# %%
# Combien de lignes ? Combien de colonnes ?
print('Il y a ' + str(df_hosts.shape[0]) + ' lignes et ' + str(df_hosts.shape[1]) + ' colonnes')
# Out:
# Il y a 53 lignes et 8 colonnes

# %%
# Y a-t'il des lignes dupliquée ? Si oui, les supprimer
print('Il y a ' + str(df_hosts.duplicated().sum()) + ' ligne(s) dupliquée(s)')
# Out:
# Il y a 0 ligne(s) dupliquée(s)

# %%
# Afficher le nombre de données manquantes pour chaque colonne
df_hosts.isnull().sum()
# Out:
# index              0
# game_slug          0
# game_end_date      0
# game_start_date    0
# game_location      0
# game_name          0
# game_season        0
# game_year          0
# dtype: int64

# %% [markdown]
# ## Fusion des dataframe medals et host

# %% [markdown]
# Comme nous pouvons nous aperçevoir, nous pouvons fusionner le DF medals (slug_game) avec le DF hosts (game_slug) qui comporte aucune données manquantes

# %%
# Fusionner les deux DataFrames en utilisant les colonnes communes
# df_merged = pd.merge(df_medals, df_hosts, left_on='slug_game', right_on='game_slug', how='inner')

# Afficher le DataFrame fusionné
df_merged
# Out:
#        Unnamed: 0 discipline_title     slug_game  \
# 0               0          Curling  beijing-2022
# 1               1          Curling  beijing-2022
# 2               2          Curling  beijing-2022
# 3               3          Curling  beijing-2022
# 4               4          Curling  beijing-2022
# ...           ...              ...           ...
# 21692       21692    Weightlifting   athens-1896
# 21693       21693    Weightlifting   athens-1896
# 21694       21694    Weightlifting   athens-1896
# 21695       21695    Weightlifting   athens-1896
# 21696       21696    Weightlifting   athens-1896
#
#                            event_title event_gender medal_type  \
# 0                        Mixed Doubles        Mixed       GOLD
# 1                        Mixed Doubles        Mixed       GOLD
# 2                        Mixed Doubles        Mixed     SILVER
# 3                        Mixed Doubles        Mixed     SILVER
# ...

# %%
df_merged.isnull().sum()
# Out:
# Unnamed: 0                   0
# discipline_title             0
# slug_game                    0
# event_title                  0
# event_gender                 0
# medal_type                   0
# participant_type             0
# participant_title        15113
# athlete_url                497
# athlete_full_name         1100
# country_name                 0
# country_code              1502
# country_3_letter_code        0
# index                        0
# game_slug                    0
# game_end_date                0
# game_start_date              0
# game_location                0
# game_name                    0
# game_season                  0
# game_year                    0
# dtype: int64

# %%
df_athletes.head()
# Out:
#                                          athlete_url       athlete_full_name  \
# 0  https://olympics.com/en/athletes/cooper-woods-...  Cooper WOODS-TOPALOVIC
# 1          https://olympics.com/en/athletes/elofsson          Felix ELOFSSON
# 2     https://olympics.com/en/athletes/dylan-walczyk           Dylan WALCZYK
# 3     https://olympics.com/en/athletes/olli-penttala           Olli PENTTALA
# 4          https://olympics.com/en/athletes/reikherd        Dmitriy REIKHERD
#
#    games_participations        first_game  athlete_year_birth athlete_medals  \
# 0                     1      Beijing 2022              2000.0           None
# 1                     2  PyeongChang 2018              1995.0           None
# 2                     1      Beijing 2022              1993.0           None
# 3                     1      Beijing 2022              1995.0           None
# 4                     1      Beijing 2022              1989.0           None
#
#     bio
# 0  None
# 1  None
# 2  None
# ...

# %%
df_athletes.isnull().sum()
# Out:
# athlete_url                 0
# athlete_full_name           0
# games_participations        0
# first_game                 22
# athlete_year_birth       2456
# athlete_medals          60552
# bio                     53062
# dtype: int64

# %% [markdown]
# On fusionne df_merged avec df_athletes pour completer les valeurs manquante dans athlete_url et athlete_full_name (sans joindre les autres colonnes de df_athletes car inutiles)

# %%
# Fusionner sur la colonne 'athlete_url' pour compléter les valeurs manquantes de 'athlete_full_name'
df_temp = pd.merge(df_merged, df_athletes[['athlete_url', 'athlete_full_name']], on='athlete_url', how='left', suffixes=('', '_athletes'))
df_merged['athlete_full_name'] = df_merged['athlete_full_name'].combine_first(df_temp['athlete_full_name_athletes'])

# Fusionner sur la colonne 'athlete_full_name' pour compléter les valeurs manquantes de 'athlete_url'
df_temp = pd.merge(df_merged, df_athletes[['athlete_full_name', 'athlete_url']], on='athlete_full_name', how='left', suffixes=('', '_athletes'))
df_merged['athlete_url'] = df_merged['athlete_url'].combine_first(df_temp['athlete_url_athletes'])

# Afficher le DataFrame mis à jour
df_merged
# Out:
#        Unnamed: 0 discipline_title     slug_game  \
# 0               0          Curling  beijing-2022
# 1               1          Curling  beijing-2022
# 2               2          Curling  beijing-2022
# 3               3          Curling  beijing-2022
# 4               4          Curling  beijing-2022
# ...           ...              ...           ...
# 21692       21692    Weightlifting   athens-1896
# 21693       21693    Weightlifting   athens-1896
# 21694       21694    Weightlifting   athens-1896
# 21695       21695    Weightlifting   athens-1896
# 21696       21696    Weightlifting   athens-1896
#
#                            event_title event_gender medal_type  \
# 0                        Mixed Doubles        Mixed       GOLD
# 1                        Mixed Doubles        Mixed       GOLD
# 2                        Mixed Doubles        Mixed     SILVER
# 3                        Mixed Doubles        Mixed     SILVER
# ...

# %%
df_merged.isnull().sum()
# Out:
# Unnamed: 0                   0
# discipline_title             0
# slug_game                    0
# event_title                  0
# event_gender                 0
# medal_type                   0
# participant_type             0
# participant_title        15113
# athlete_url                109
# athlete_full_name           80
# country_name                 0
# country_code              1502
# country_3_letter_code        0
# index                        0
# game_slug                    0
# game_end_date                0
# game_start_date              0
# game_location                0
# game_name                    0
# game_season                  0
# game_year                    0
# dtype: int64

# %%
df_results
# Out:
#         Unnamed: 0     discipline_title  \
# 0                0              Curling
# 1                1              Curling
# 2                2              Curling
# 3                3              Curling
# 4                4              Curling
# ...            ...                  ...
# 162799      162799          Ski Jumping
# 162800      162800          Ski Jumping
# 162801      162801          Ski Jumping
# 162802      162802          Ski Jumping
# 162803      162803  Gymnastics Artistic
#
#                                               event_title      slug_game  \
# 0                                           Mixed Doubles   beijing-2022
# 1                                           Mixed Doubles   beijing-2022
# 2                                           Mixed Doubles   beijing-2022
# 3                                           Mixed Doubles   beijing-2022
# 4                                           Mixed Doubles   beijing-2022
# ...

# %%
df_results.isnull().sum()
# Out:
# Unnamed: 0                    0
# discipline_title              0
# event_title                   0
# slug_game                     0
# participant_type              0
# medal_type               142598
# athletes                 154828
# rank_equal               130278
# rank_position              3878
# country_name                  0
# country_code               5036
# country_3_letter_code         0
# athlete_url               32813
# athlete_full_name         21158
# value_unit                84158
# value_type                72755
# dtype: int64

# %% [markdown]
# les données communes et sans null:
# - discipline_title
# - event_title
# - slug_game
# - participant_types
# - country_name
# - country_3_letter_code
#
# Les données intéressantes :
# - rank_position
# - athlete_url
# - athlete_full_name

# %% [markdown]
# ## Nettoyage des données

# %% [markdown]
# Nous avons nos 4 dataframes Athlètes, résulats, médailles, hôtes.
# Le but est maintenant de 'nettoyer' les données car comme on peut voir il y a beaucoup de données manquantes dans les DF dont 'résultats' et 'médailles'

# %% [markdown]
# #### Nettoyage du DF Athletes

# %%
# df_athletes.head()

# %%
# df_athletes.isnull().sum()

# %%
# Filtrer les lignes où athlete_medals n'est pas nul
# filtered_df = df_athletes[df_athletes['athlete_medals'].notnull()]

# Afficher le DataFrame filtré
# filtered_df

# %%
# Suppression des colonnes inutiles
# df_athletes.drop(columns=["athlete_year_birth", "athlete_medals", "bio"], inplace=True)
# df_athletes.head()

# %% [markdown]
# #### Nettoyage du DF Résults

# %%
# df_results.head()

# %%
# df_results.isnull().sum()

# %%
# Suppression des colonnes inutiles
# df_results.drop(columns=["athletes", "rank_equal"], inplace=True)
# df_results.head()

# %% [markdown]
# #### Nettoyage du DF Médailles

# %%
# df_medals.head()

# %%
# df_medals.isnull().sum()

# %%
# Suppression des colonnes inutiles
# df_medals.drop(columns=["participant_title", "country_code"], inplace=True)
# df_medals.head()

# %% [markdown]
# #### Nettoyage du DF Host

# %%
# df_hosts.head()

# %%
# df_hosts.isnull().sum()

# %% [markdown]
# On supprime les données inutiles:
